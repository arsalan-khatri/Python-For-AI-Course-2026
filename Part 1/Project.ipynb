# %% [markdown]
# ## Mini rulebase Chatbot Project

# %%
import random # Library

print("Hello! Main Chota Jarvis hoon.") 

name = input("Aapka naam kya hai? ")

if "Arsalan" in name:
    print(f"Welcome Boss {name}! Access Granted.")
else:
    print(f"Hello {name}, sorry main aapko nahi jaanta.")

moods = ["Happy", "Sad", "Angry"] # List
print(f"Aaj mera mood {random.choice(moods)} hai.")
# Out:
# Hello! Main Chota Jarvis hoon.
# Aapka naam kya hai?  Arsalan
# Welcome Boss Arsalan! Access Granted.
# Aaj mera mood Happy hai.

# %% [markdown]
# ## Your Task

# %% [markdown]
# Task Statement: "Aapko ek Club ka Security System banana hai."
#
# User se uski Age poocho.
#
# Agar Age 18 se kam hai ➔ Print: "Bhaag ja yahan se, bachche allow nahi hain."
#
# Agar Age 18 ya usse zyada hai ➔ To poocho: "Kya tumhare paas VIP Pass hai? (Yes/No)"
#
# Agar Yes ➔ "Welcome Sir!"
#
# Agar No ➔ "Line mein lago!"
