# %% [markdown]
# ## Part 1 Explanation

# %% [markdown]
# ### 1) Variables and Datatypes
# ### 2) Input and Output
# ### 3) Conditional Statement
# ### 4) lists
# ### 5) import libraries
# ### 6) Mini Rule Based Chatbot Project

# %%
name = "Arsalan Khatri"
age = 20
number = 23.05
boolean = True

# %%
type(name)
# Out:
# str

# %%
name = input("Enter your name : ")
# Out:
# Enter your name :  Arsalan

# %%
print(f"Hi! {name}")
# Out:
# Hi! Arsalan

# %%
num = 50
if num < 20:
    print(f"Number {num} is less then 20")
else:
    print(f"Number {num} is greater then 20")
# Out:
# Number 50 is greater then 20

# %%
fruits = ['Apple','Mango','Orange',20,30.50,True]

# %%
type(fruits)
# Out:
# list

# %%
import random as rn

# %%
rn.choice(fruits)
# Out:
# True
